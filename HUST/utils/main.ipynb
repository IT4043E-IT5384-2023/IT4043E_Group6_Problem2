# %%
import json
from datetime import datetime
# import pandas as pd

# %%
# Out:
# python: can't open file '/home/kc/ducntm/HUST/utils/setup.py': [Errno 2] No such file or directory

# %%
users_path = "../QuestN/data/users/{}".format(datetime.utcnow().date())
quests_path = "../QuestN/data/all_quests-{}.json".format(datetime.utcnow().date())

# %%
with open(quests_path, 'r') as f:
    data = json.load(f)

# %%
sample = data[0]

# %%
sample
# Out:
# {'id': '850276234758266917',
#  'community_id': '823049978105032922',
#  'title': 'Micro3 Mainnet Marvel: Unleashing the Power with BNB Chain',
#  'status': 300,
#  'start_time': 1703145600,
#  'end_time': 1704499200,
#  'numbers': 100,
#  'priority': 0,
#  'identity': 1,
#  'distribution_method': 100,
#  'gasless': 0,
#  'related_type': 100,
#  'basic': {'id': '850276234758266917',
#   'community_info': {'id': '823049978105032922',
#    'url': 'Micro3',
#    'name': 'Micro3',
#    'introduction': 'Micro3 is a versatile platform for seamless cross-chain interactions in the Web3 space. We prioritize a secure, versatile multi-chain ecosystem, simplifying transactions and supporting diverse tokens.',
#    'identity': 100,
#    'extra': {'website': '',
#     'telegram': '',
#     'discord': 'https://discord.gg/RZcFftRpT3'},
#    'logo': 'https://s3.ap-northeast-1.amazonaws.com/quest3.xyz/community/825635612163371206.png',
#    'background': '',
#    'twitter_uid': '1432012870821105671',
# ...

# %%
sample["basic"]['community_info']['introduction']
# Out:
# 'Micro3 is a versatile platform for seamless cross-chain interactions in the Web3 space. We prioritize a secure, versatile multi-chain ecosystem, simplifying transactions and supporting diverse tokens.'

# %%
def get_project_infor(sample):
    project_id = sample['id']
    description = sample['community_info']['introduction']
    return project_id, description

# %%
for sample in data:
    print(get_project_infor(sample))
# Out:
# ('850276234758266917', 'Micro3 is a versatile platform for seamless cross-chain interactions in the Web3 space. We prioritize a secure, versatile multi-chain ecosystem, simplifying transactions and supporting diverse tokens.')
# ('851990277962326376', '🌏 Eastern Cultural Vision NFT Marketplace 🪙 \n⛩️ Your Gateway to the Web 3.0 World & Digital Oasis 🌵')
# ('852020597648183793', 'Ave.ai is a decentralized on-chain data platform that currently aggregates on-chain data from 40+ blockchains.\nProvide users with the K-line data of the token, the floor price of nft, and the statistical data of various sectors such as DeFi, GameFi, and Web3.0, etc.\nAnd committed to developing a "safer, more accurate, and more professional" aggregated data platform.')
# ('852009807925412281', '🌊 Nami Official is a cryptocurrency community where investors are able to discover innovative financial technology products including Nami Exchange, Nami Insurance, Nami Frame.\n\n\n\n\n\n')
# ...

# %%
sample = data[0]

# %%
sample["community_info"]
# Out:
# {'id': '823049978105032922',
#  'url': 'Micro3',
#  'name': 'Micro3',
#  'introduction': 'Micro3 is a versatile platform for seamless cross-chain interactions in the Web3 space. We prioritize a secure, versatile multi-chain ecosystem, simplifying transactions and supporting diverse tokens.',
#  'identity': 100,
#  'extra': {'website': '',
#   'telegram': '',
#   'discord': 'https://discord.gg/RZcFftRpT3'},
#  'logo': 'https://s3.ap-northeast-1.amazonaws.com/quest3.xyz/community/825635612163371206.png',
#  'background': '',
#  'twitter_uid': '1432012870821105671',
#  'twitter_name': 'Micro3',
#  'twitter_username': 'Micro3io',
#  'created_time': '2023-10-02T07:06:46.453Z',
#  'followers_count': 1658,
#  'is_followed': False,
#  'user_rp_value': 0,
#  'user_ongoing_count': 0,
#  'quest_count': 31,
#  'questers': 13337,
#  'members': [{'user_id': '742228473367142894',
#    'user_name': 'lastofthetenthousand.eth',
# ...

# %%
Micro3 is a versatile platform for seamless cross-chain interactions in the Web3 space. We prioritize a secure, versatile multi-chain ecosystem, simplifying transactions and supporting diverse tokens.
